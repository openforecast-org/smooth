# %%
import numpy as np
import pandas as pd

from smooth import ADAM

df = pd.read_csv("../data/etsx_data.csv")

y = df["y"]
X = df[["x1", "x2"]]

model = ADAM(model="AAN", regressors="use", h=5, holdout=True, smoother="global")
model.fit(y, X)


print(model.summary())

model.predict(5, X.tail(5))
# Out:
# Model estimated using ADAM() function: ETSX(AAN)
# Response variable: y
# Distribution used in the estimation: Normal
# Loss function type: likelihood; Loss function value: 157.4708
# Coefficients:
#        Estimate  Std. Error  Lower 2.5%  Upper 97.5%
# alpha    0.0223      0.0200      0.0000       0.0619
# beta     0.0000      0.0002      0.0000       0.0003
# xreg1    1.8859      0.0875      1.7126       2.0591  *
# xreg2   -1.4746      0.0996     -1.6718      -1.2774  *
# Error standard deviation: 0.9516
# Sample size: 115
# Number of estimated parameters: 5
# Number of degrees of freedom: 110
# Information criteria:
#      AIC    AICc      BIC     BICc
# 324.9415 325.492 338.6662 339.9721
#           mean
# 115   9.499318
# 116   6.680249
# 117  14.756861
# 118   6.690754
# 119  11.260099

# %%
from fcompdata import M3
from smooth import ADAM

series = M3[2568]

# Fit model
model = ADAM(model="ZXZ", lags=[1,series.period],
            #  ar_order=[1,1], i_order=[1,1], ma_order=[1,2],
             initial="backcasting",
             nlopt_kargs={"print_level": 0,
                          "maxeval": 0},
             holdout=True, h=18)

model.fit(series.x)

print(model)

model.plot(7)
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[2], line 14
#
#       6 # Fit model
#
#       7 model = ADAM(model="ZXZ", lags=[1,series.period],
#
#       8             #  ar_order=[1,1], i_order=[1,1], ma_order=[1,2],
#
#       9              initial="backcasting",
#
#      10              nlopt_kargs={"print_level": 0,
#
#      11                           "maxeval": 0},
#
#      12              holdout=True, h=18)
#
# ---> 14 model.fit(series.x)
#
#      16 print(model)
#
#      18 model.plot(7)
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:904, in ADAM.fit(self, y, X)
#
#     901     self._execute_estimation()
#
#     902 elif self._model_type["model_do"] == "select":
#
#     903     # get the best model
#
# --> 904     self._execute_selection()
#
#     905     # Execute estimation for the selected model
#
#     906     # Note: estimator() handles two-stage initialization internally,
#
#     907     # so all models in the pool use consistent initialization
#
#     908     self._execute_estimation(estimation=True)
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:3227, in ADAM._execute_selection(self)
#
#    3221 """
#
#    3222 Execute model selection when model_do is 'select'.
#
#    3223
#
#    3224 This handles model selection and creation of the selected model.
#
#    3225 """
#
#    3226 # Run model selection
#
# -> 3227 self._adam_selected = selector(
#
#    3228     model_type_dict=self._model_type,
#
#    3229     phi_dict=self._phi_internal,
#
#    3230     general_dict=self._general,
#
#    3231     lags_dict=self._lags_model,
#
#    3232     observations_dict=self._observations,
#
#    3233     arima_dict=self._arima,
#
#    3234     constant_dict=self._constant,
#
#    3235     explanatory_dict=self._explanatory,
#
#    3236     occurrence_dict=self._occurrence,
#
#    3237     components_dict=self._components,
#
#    3238     profiles_recent_table=self.profiles_recent_table,
#
#    3239     profiles_recent_provided=self.profiles_recent_provided,
#
#    3240     persistence_results=self._persistence,
#
#    3241     initials_results=self._initials,
#
#    3242     criterion=self._general["ic"],
#
#    3243     silent=self.verbose == 0,
#
#    3244     nlopt_kargs=self.nlopt_kargs,
#
#    3245     smoother=self.smoother,
#
#    3246 )
#
#    3247 # print(self._adam_selected)
#
#    3248 # print(self._adam_selected["ic_selection"])
#
#    3249
#
#    3250 # Updates parametes with the selected model and updates adam_estimated
#
#    3251 self.select_best_model()
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator/selector.py:1039, in selector(model_type_dict, phi_dict, general_dict, lags_dict, observations_dict, arima_dict, constant_dict, explanatory_dict, occurrence_dict, components_dict, profiles_recent_table, profiles_recent_provided, persistence_results, initials_results, criterion, silent, nlopt_kargs, smoother)
#
#    1036     model_type_dict["models_pool"] = list(dict.fromkeys(combined_models))
#
#    1038 # Step 3: Estimate all models in the pool (skip already tested models)
#
# -> 1039 results = _estimate_all_models(
#
#    1040     model_type_dict["models_pool"],
#
#    1041     model_type_dict,
#
#    1042     phi_dict,
#
#    1043     general_dict,
#
#    1044     lags_dict,
#
#    1045     observations_dict,
#
#    1046     arima_dict,
#
#    1047     constant_dict,
#
#    1048     explanatory_dict,
#
#    1049     profiles_recent_table,
#
#    1050     profiles_recent_provided,
#
#    1051     persistence_results,
#
#    1052     initials_results,
#
#    1053     occurrence_dict,
#
#    1054     components_dict,
#
#    1055     silent,
#
#    1056     nlopt_kargs=nlopt_kargs,
#
#    1057     precomputed_results=bb_results,
#
#    1058     precomputed_models=bb_models_tested,
#
#    1059     smoother=smoother,
#
#    1060 )
#
#    1061 # print(results)
#
#    1062
#
#    1063 # Step 4: Extract ICs and find the best model
#
#    1064 models_number = len(model_type_dict["models_pool"])
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator/selector.py:656, in _estimate_all_models(models_pool, model_type_dict, phi_dict, general_dict, lags_dict, observations_dict, arima_dict, constant_dict, explanatory_dict, profiles_recent_table, profiles_recent_provided, persistence_results, initials_results, occurrence_dict, components_dict, silent, nlopt_kargs, precomputed_results, precomputed_models, smoother)
#
#     654 # Estimate the model
#
#     655 results[j] = {}
#
# --> 656 results[j]["adam_estimated"] = estimator(
#
#     657     general_dict=general_dict,
#
#     658     model_type_dict=model_type_dict_temp,
#
#     659     lags_dict=lags_dict,
#
#     660     observations_dict=observations_dict,
#
#     661     arima_dict=arima_dict,
#
#     662     constant_dict=constant_dict,
#
#     663     explanatory_dict=explanatory_dict,
#
#     664     profiles_recent_table=profiles_recent_table,
#
#     665     profiles_recent_provided=profiles_recent_provided,
#
#     666     persistence_dict=persistence_results,
#
#     667     initials_dict=initials_results,
#
#     668     occurrence_dict=occurrence_dict,
#
#     669     phi_dict=phi_dict_temp,
#
#     670     components_dict=components_dict,
#
#     671     **(nlopt_kargs or {}),
#
#     672     smoother=smoother,
#
#     673 )
#
#     674 results[j]["IC"] = ic_function(
#
#     675     general_dict["ic"],
#
#     676     loglik=results[j]["adam_estimated"]["log_lik_adam_value"],
#
#     677 )
#
#     678 results[j]["model_type_dict"] = model_type_dict_temp
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator/estimator.py:571, in estimator(general_dict, model_type_dict, lags_dict, observations_dict, arima_dict, constant_dict, explanatory_dict, profiles_recent_table, profiles_recent_provided, persistence_dict, initials_dict, phi_dict, components_dict, occurrence_dict, multisteps, lb, ub, maxtime, print_level, maxeval, B_initial, return_matrices, other, other_parameter_estimate, xtol_rel, xtol_abs, ftol_rel, ftol_abs, algorithm, smoother, adam_ets, fi, step_size)
#
#     568 opt.set_min_objective(objective_wrapper)
#
#     570 # Step 9: Run optimization
#
# --> 571 B[:] = _run_optimization(opt, B)
#
#     572 CF_value = opt.last_optimum_value()
#
#     574 # Step 9a: a BOBYQA refinement pass was tried in the past but produced
#
#     575 # less stable ARIMA estimates, so only the Nelder-Mead pass is run.
#
#     576
#
#     577 # Step 10a: Retry optimisation with zero smoothing parameters if the
#
#     578 # initial optimisation failed to converge (non-finite or penalty-valued
#
#     579 # cost function).
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator/optimization.py:369, in _run_optimization(opt, B)
#
#     366 # Run optimization - nlopt updates B in-place and returns optimized values
#
#     367 # Any nlopt termination (including RoundoffLimited) still returns valid B
#
#     368 try:
#
# --> 369     x = opt.optimize(B)
#
#     370 except Exception:
#
#     371     # If any exception, B has still been updated in-place
#
#     372     x = B.copy()
#
#
#
# File ~/Python/Libraries/smooth/python/.venv/lib/python3.14/site-packages/nlopt/nlopt.py:452, in opt.optimize(self, *args)
#
#     451 def optimize(self, *args):
#
# --> 452     return _nlopt.opt_optimize(self, *args)
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator/optimization.py:305, in _create_objective_function.<locals>.objective_wrapper(x, grad)
#
#     303 # Calculate the cost function with exception handling
#
#     304 try:
#
# --> 305     cf_value = CF(
#
#     306         B=x,
#
#     307         model_type_dict=model_type_dict,
#
#     308         components_dict=components_dict,
#
#     309         lags_dict=lags_dict,
#
#     310         matrices_dict=adam_created,
#
#     311         persistence_checked=persistence_dict,
#
#     312         initials_checked=initials_dict,
#
#     313         arima_checked=arima_dict,
#
#     314         explanatory_checked=explanatory_dict,
#
#     315         phi_dict=phi_dict,
#
#     316         constants_checked=constant_dict,
#
#     317         observations_dict=observations_dict,
#
#     318         profile_dict=profile_dict,
#
#     319         general=general_dict,
#
#     320         adam_cpp=adam_cpp,
#
#     321         bounds=general_dict["bounds"],
#
#     322         other=other,
#
#     323         otherParameterEstimate=other_parameter_estimate,
#
#     324         arPolynomialMatrix=ar_polynomial_matrix,
#
#     325         maPolynomialMatrix=ma_polynomial_matrix,
#
#     326     )
#
#     327 except Exception:
#
#     328     cf_value = 1e100
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/cost_functions.py:498, in CF(B, model_type_dict, components_dict, lags_dict, matrices_dict, persistence_checked, initials_checked, arima_checked, explanatory_checked, phi_dict, constants_checked, observations_dict, profile_dict, general, adam_cpp, bounds, other, otherParameterEstimate, arPolynomialMatrix, maPolynomialMatrix, regressors)
#
#     496 if not general["multisteps"]:
#
#     497     if general["loss"] == "likelihood":
#
# --> 498         scale = scaler(
#
#     499             general["distribution_new"],
#
#     500             model_type_dict["error_type"],
#
#     501             adam_fitted.errors[observations_dict["ot_logical"]],
#
#     502             adam_fitted.fitted[observations_dict["ot_logical"]],
#
#     503             observations_dict["obs_in_sample"],
#
#     504             other,
#
#     505         )
#
#     506         # print(adam_fitted.errors)
#
#     507         # Calculate the likelihood
#
#     508         CFValue = -np.sum(
#
#     509             calculate_likelihood(
#
#     510                 general["distribution_new"],
#
#    (...)
#
#     516             )
#
#     517         )
#
#
#
# File ~/Misc/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:643, in scaler(distribution, Etype, errors, y_fitted, obs_in_sample, other)
#
#     639     else:
#
#     640         return 0
#
# --> 643 def scaler(distribution, Etype, errors, y_fitted, obs_in_sample, other):
#
#     644     """
#
#     645     Calculate scale parameter for the provided parameters.
#
#     646
#
#    (...)
#
#     656     float: The calculated scale parameter
#
#     657     """
#
#     659     # Helper: take ``log`` of a possibly-negative input via complex extension.
#
#     660     # ``log(as.complex(z))`` for z < 0 yields ``log|z| + iπ``; downstream the
#
#     661     # modulus ``abs(...)`` is taken so the result is finite and continuous.
#
#     662     # Mirrors R's ``log(as.complex(...))`` pattern used in ``adam_scaler``.
#
#
#
# KeyboardInterrupt:

# %%
from fcompdata import M3
from smooth import AutoADAM

series = M3[2568]

# Fit model
model = AutoADAM(model="ANN", lags=[1,series.period],
                 orders={"ar": [3,3], "i": [2,2], "ma": [3,3]},
                 arima_select=True,
                 initial="backcasting",
                 nlopt_kargs={"print_level": 0,
                              "maxeval": 1})

model.fit(series.x)

print(model)
# Out:
# Time elapsed: 3.69 seconds
# Model estimated using ADAM() function: ETS(ANN)+SARIMA(3,0,0)[1](0,1,1)[12] with drift
# With backcasting initialisation
# Distribution assumed in the model: Log-Normal
# Loss function type: likelihood; Loss function value: 872.0257
# Intercept/Drift value: 77.6781
# Persistence vector g:
#  alpha
# 0.0047
# ARMA parameters of the model:
#              Lag 1
# AR(1)       0.0339
# AR(2)       0.1965
# AR(3)       0.4795
#             Lag 12
# MA(1)      -0.1571
# Sample size: 116
# Number of estimated parameters: 7
# Number of degrees of freedom: 109
# Information criteria:
#       AIC      AICc       BIC      BICc
# 1758.0513 1759.0883 1777.3264 1779.7913

# %%
from fcompdata import M3
from smooth import ES

series = M3[2568]

# Fit model
model = ES(model="ZXZ", lags=[series.period],
             holdout=True, h=18, initial="optimal")

model.fit(series.x)

# print(model)

model.predict(h=18, interval="prediction")

model.summary()

# model.plot(7)
# Out:
#            b1        b2        b3           b4          b5        b6  \
# b1   0.009355  0.000510  0.003355    -3.346033   -0.850278  0.000282
# b2   0.000510  0.000012  0.000142    -0.465836   -0.022362  0.000017
# b3   0.003355  0.000142 -0.003935    -1.825990   -0.234060 -0.000036
# b4  -3.346033 -0.465836 -1.825990  4778.995196  625.756744 -0.123110
# b5  -0.850278 -0.022362 -0.234060   625.756744   42.307395 -0.029180
# b6   0.000282  0.000017 -0.000036    -0.123110   -0.029180  0.000389
# b7  -0.000637 -0.000022  0.000607     0.526875    0.036144 -0.000032
# b8  -0.000324 -0.000015  0.000161     0.154317    0.026630 -0.000043
# b9   0.000820  0.000030 -0.000512    -0.833283   -0.050786  0.000005
# b10  0.000311  0.000011 -0.000299    -0.204830   -0.015812 -0.000047
# b11  0.000125  0.000002 -0.000024    -0.259082   -0.004633 -0.000008
# b12 -0.000293 -0.000012  0.000160     0.205650    0.020797 -0.000035
# b13 -0.000280 -0.000012  0.000265     0.183800    0.019596 -0.000030
# b14  0.000210  0.000007 -0.000239    -0.205850   -0.012878 -0.000012
# b15  0.000077  0.000004 -0.000131     0.035566   -0.006499 -0.000033
# b16  0.000133  0.000006 -0.000172     0.024987   -0.010197 -0.000035
#
#                b7        b8            b9           b10           b11  \
# b1  -6.372859e-04 -0.000324  8.203940e-04  3.110076e-04  1.250897e-04
# b2  -2.159729e-05 -0.000015  3.032981e-05  1.057724e-05  2.346892e-06
# b3   6.065325e-04  0.000161 -5.124013e-04 -2.990548e-04 -2.377099e-05
# b4   5.268749e-01  0.154317 -8.332828e-01 -2.048296e-01 -2.590819e-01
# b5   3.614359e-02  0.026630 -5.078625e-02 -1.581218e-02 -4.632760e-03
# b6  -3.151326e-05 -0.000043  5.353702e-06 -4.650231e-05 -8.457662e-06
# b7   2.569408e-04 -0.000068  4.467369e-05  5.299253e-07 -3.036375e-05
# b8  -6.780630e-05  0.000415 -2.650314e-05 -4.010277e-05 -4.277261e-05
# b9   4.467369e-05 -0.000027  4.269588e-04 -8.778767e-05  5.804569e-07
# b10  5.299253e-07 -0.000040 -8.778767e-05  3.824893e-04 -4.948972e-05
# b11 -3.036375e-05 -0.000043  5.804569e-07 -4.948972e-05  4.401476e-04
# b12 -6.520916e-05 -0.000052 -1.694131e-05 -3.813511e-05 -3.567872e-05
# b13 -7.999263e-05 -0.000056  3.741953e-06 -2.863857e-05 -3.109315e-05
# b14  2.795937e-06 -0.000033 -3.192244e-05 -6.625016e-05 -1.394538e-05
# b15 -2.077879e-05 -0.000041 -4.908360e-05 -5.944893e-05 -3.474606e-05
# b16 -1.555975e-05 -0.000041 -5.794457e-05 -6.308348e-05 -3.772635e-05
#
#           b12       b13       b14       b15       b16
# b1  -0.000293 -0.000280  0.000210  0.000077  0.000133
# b2  -0.000012 -0.000012  0.000007  0.000004  0.000006
# b3   0.000160  0.000265 -0.000239 -0.000131 -0.000172
# b4   0.205650  0.183800 -0.205850  0.035566  0.024987
# b5   0.020797  0.019596 -0.012878 -0.006499 -0.010197
# b6  -0.000035 -0.000030 -0.000012 -0.000033 -0.000035
# b7  -0.000065 -0.000080  0.000003 -0.000021 -0.000016
# b8  -0.000052 -0.000056 -0.000033 -0.000041 -0.000041
# b9  -0.000017  0.000004 -0.000032 -0.000049 -0.000058
# b10 -0.000038 -0.000029 -0.000066 -0.000059 -0.000063
# b11 -0.000036 -0.000031 -0.000014 -0.000035 -0.000038
# b12  0.000398 -0.000052 -0.000025 -0.000037 -0.000036
# b13 -0.000052  0.000383 -0.000016 -0.000032 -0.000031
# b14 -0.000025 -0.000016  0.000409 -0.000040 -0.000045
# b15 -0.000037 -0.000032 -0.000040  0.000386 -0.000047
# b16 -0.000036 -0.000031 -0.000045 -0.000047  0.000376

# %%
from fcompdata import M3
from smooth import ES

series = M3[1687]

# Fit model
model = ES(model="CXC", lags=[series.period],
             holdout=True, h=18)

model.fit(series.x)

# print(model)

model.predict(h=18, interval="prediction")

model.plot(7)

# %%
from smooth import ES
from fcompdata import PromoData

model = ES(model="MNM", lags=52, holdout=True, h=13)
model.fit(PromoData.y)
model.predict(h=18)
model.plot(7)

# model.summary()
# Out:
# Model estimated using ES() function: ETS(MNM)
# Response variable: y
# Distribution used in the estimation: Normal
# Loss function type: likelihood; Loss function value: 1045.8568
# Coefficients:
#        Estimate  Std. Error  Lower 2.5%  Upper 97.5%
# alpha    0.2086      0.0493      0.1112       0.3059  *
# gamma    0.0000      0.0622      0.0000       0.1230
# Error standard deviation: 0.1542
# Sample size: 143
# Number of estimated parameters: 3
# Number of degrees of freedom: 140
# Information criteria:
# AIC     2097.7136
# AICc    2097.8862
# BIC     2106.6021
# BICc    2107.0305

# %%
from smooth import ADAM
from fcompdata import PromoData

model = ADAM(model="MNM", lags=52, holdout=True, h=13)
model.fit(PromoData.y, PromoData.xreg)
model.predict(h=13, X=PromoData.xregxx)
model.plot(7)

# %%
from fcompdata import AirPassengers
from smooth import AutoADAM, ADAM

model = AutoADAM(lags=[12], h=12, holdout=False, orders=None, verbose=True)
# model = ADAM(lags=[12], h=12, holdout=False, orders=None, verbose=True, distribution="dgnorm", initial="optimal")
model.fit(AirPassengers.y)
# model.summary()
model.plot(6)
# Out:
# Evaluating models with different distributions... dnorm, dlaplace, ds, dgnorm, dlnorm, dinvgauss, dgamma, Done!
# Selected distribution: dnorm

# %%
from fcompdata import AirPassengers
from smooth import AutoADAM, ADAM

# ETS(A,A,N) + Seasonal ARIMA(1,1,1)
model = ADAM(
    model="AAN",
    ar_order=[0, 1],
    i_order=[0, 1],
    ma_order=[0, 1],
    lags=[1, 12],
    h=12, holdout=True
)
model.fit(AirPassengers.y)
model.predict(h=12, interval="prediction", level=0.95)
print(model)
model.plot(7)
# Out:
# Time elapsed: 0.04 seconds
# Model estimated using ADAM() function: ETS(AAN)+SARIMA(1,1,1)[12]
# With backcasting initialisation
# Distribution assumed in the model: Normal
# Loss function type: likelihood; Loss function value: 499.8270
# Persistence vector g:
#  alpha   beta
# 0.2952 0.0002
# ARMA parameters of the model:
#             Lag 12
# AR(1)      -0.9493
#             Lag 12
# MA(1)       0.8087
# Sample size: 132
# Number of estimated parameters: 31
# Number of degrees of freedom: 101
# Information criteria:
#       AIC      AICc       BIC      BICc
# 1061.6539 1081.4939 1151.0208 1199.4582
#
# Forecast errors:
# ME: 5.2324; MAE: 12.9050; RMSE: 16.2093
# sCE: 23.9203%; Asymmetry: 48.6%; sMAE: 4.9163%; sMSE: 0.3813%
# MASE: 0.5358; RMSSE: 0.5173; rMAE: 0.1698; rRMSE: 0.1574

# %%
from fcompdata import taylor
from smooth import MSARIMA

# MSARIMA(3,0,1)(0,1,1)[48](0,1,1)[336]
model = MSARIMA(
    orders={"ar": [3, 0, 0], "i": [0, 1, 1], "ma": [1, 1, 1]},
    lags=[1, 48, 336],
    h=336, holdout=True
)
model.fit(taylor.y)
model.predict(h=336, interval="prediction", level=0.95)
print(model)
# Out:
# /home/config/Misc/Python/Libraries/openforecast-org/smooth/python/src/smooth/adam_general/core/utils/utils.py:863: RuntimeWarning: overflow encountered in square
#   return np.sqrt(_sum_r(errors**2) / obs_in_sample)
# Time elapsed: 1.52 seconds
# Model estimated using ADAM() function: SARIMA(3,0,1)[1](0,1,1)[48](0,1,1)[336]
# With backcasting initialisation
# Distribution assumed in the model: Normal
# Loss function type: likelihood; Loss function value: 25674.0875
# ARMA parameters of the model:
#              Lag 1
# AR(1)       0.1602
# AR(2)       0.1562
# AR(3)      -0.0102
#              Lag 1       Lag 48      Lag 336
# MA(1)       0.7566      -0.3709      -0.5583
# Sample size: 3696
# Number of estimated parameters: 394
# Number of degrees of freedom: 3302
# Information criteria:
#       AIC      AICc       BIC      BICc
# 52136.1750 52230.4676 54584.8875 54972.1948
#
# Forecast errors:
# ME: 62.7033; MAE: 372.4222; RMSE: 497.1329
# sCE: 71.2023%; Asymmetry: 27.4%; sMAE: 1.2586%; sMSE: 0.0282%
# MASE: 0.5728; RMSSE: 0.5267; rMAE: 0.0557; rRMSE: 0.0607
